# %% [markdown]
# <a href="https://colab.research.google.com/github/ManelBoucenna/AI-s-code-repository/blob/master/Irisflower_w_t_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inspired from: https://www.youtube.com/watch?v=RmajweUFKvM&list=PLEiEAq2VkUULNa6MHQAZSOBxzB6HHFXj4&index=3

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.model_selection import train_test_split
from IPython.display import Image  
import pydotplus

# %%
X = load_iris().data
Y = load_iris().target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = .3, random_state = 100)
model = DecisionTreeClassifier(criterion="entropy", random_state=100, max_depth=3, min_samples_leaf = 5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=100, splitter='best')

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 1, 1, 2, 2, 2, 2, 0,
#        2, 0, 1, 2, 1, 0, 1, 2, 1, 1, 1, 0, 0, 1, 0, 1, 2, 2, 0, 1, 2, 2,
#        0])

# %%
print("Accuracy is ", accuracy_score(y_test, y_pred)*100)
# Out:
# Accuracy is  95.55555555555556

# %%
# Create DOT data
dot_data = tree.export_graphviz(model, out_file=None, 
                                feature_names=load_iris().feature_names,  
                                class_names=load_iris().target_names)

# Draw graph
graph = pydotplus.graph_from_dot_data(dot_data)  

# Show graph
Image(graph.create_png())
